# %% [markdown]
# Task3 : Controlable Niose Map Observation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.stats import ttest_ind, mannwhitneyu, ks_2samp, shapiro, levene
import numpy as np
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /speed-scratch/se_gham/HOB/Hybrid-OOD-Detection-in-BSR/analyse/Controlable_noisemap_observation.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://localhost:9000/speed-scratch/se_gham/HOB/Hybrid-OOD-Detection-in-BSR/analyse/Controlable_noisemap_observation.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell://localhost:9000/speed-scratch/se_gham/HOB/Hybrid-OOD-Detection-in-BSR/analyse/Controlable_noisemap_observation.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell://localhost:9000/speed-scratch/se_gham/HOB/Hybrid-OOD-Detection-in-BSR/analyse/Controlable_noisemap_observation.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Data summary

# %%
# Load the data (assuming the dataframes real_df and syn_df are available)
real_df = pd.read_csv('../results/stage2/Task4/3/results-3-real.csv')
syn_df = pd.read_csv('../results/stage2/Task4/3/results-3-syn.csv')

# Merging the real and synthetic DataFrames for analysis
merged_df = pd.merge(real_df, syn_df, on=['Image_Index', 'Noise_level'], suffixes=('_real', '_syn'))

# Preview the first few rows
print(merged_df.head())
# Out:
#    Image_Index Noise_level  PSNR_real  SSIM_real  LPIPS_real  BRISQUE_real  \
# 0            0        high  25.225878   0.946783    0.488028     70.194275
# 1            0         mid  19.281309   0.897228    0.608931     34.169128
# 2            0         low  22.272856   0.948090    0.220972     92.234436
# 3            1        high  25.290358   0.950145    0.503042     72.713806
# 4            1         mid  19.486982   0.946562    0.172984    100.452026
#
#    MUSIQ_real  NIMA_real  NIQE_real   PSNR_syn  SSIM_syn  LPIPS_syn  \
# 0   22.131226   2.514439  11.259880  23.965740  0.948646   0.420798
# 1   36.558865   3.214453   9.360005  19.586870  0.921490   0.185342
# 2   19.665245   3.316759  20.543077  18.657621  0.759324   0.638172
# 3   22.784182   2.526016  10.941504  24.383865  0.950526   0.388705
# 4   31.480690   3.035587  26.171356  19.519091  0.921870   0.236295
#
#    BRISQUE_syn  MUSIQ_syn  NIMA_syn   NIQE_syn
# 0    70.070496  25.272955  2.898843  13.206671
# 1   104.618347  20.690815  2.649604  20.107821
# 2     7.694641  24.084005  2.838799   7.821658
# 3    68.748718  24.055407  2.870017  12.481927
# 4    92.960388  24.440598  3.364453  25.603756

# %% [markdown]
# Histogram Visualization

# %%
# Metrics to visualize
metrics = ['PSNR', 'SSIM', 'LPIPS', 'BRISQUE', 'MUSIQ', 'NIMA', 'NIQE']

# 1. Histogram Distribution for Each Metric by Noise Level
plt.figure(figsize=(20, 30))
for idx, metric in enumerate(metrics):
    for noise_level in ['high', 'mid', 'low']:
        plt.subplot(len(metrics), 3, idx * 3 + ['high', 'mid', 'low'].index(noise_level) + 1)
        sns.kdeplot(real_df[real_df['Noise_level'] == noise_level][metric], label=f'Real - {noise_level}', linestyle='-')
        sns.kdeplot(syn_df[syn_df['Noise_level'] == noise_level][metric], label=f'Syn - {noise_level}', linestyle='--')
        plt.title(f'Histogram Distribution for {metric} - {noise_level} Noise')
        plt.xlabel(metric)
        plt.ylabel('Density')
        plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Statistical Analyse

# %% [markdown]
# 1 - Bar Plots

# %%
# 2. Bar Plots for Average Differences by Noise Level
# Calculating differences
for metric in metrics:
    merged_df[f'{metric}_diff'] = merged_df[f'{metric}_real'] - merged_df[f'{metric}_syn']
noise_level_diff_summary = merged_df.groupby('Noise_level')[[f'{metric}_diff' for metric in metrics]].mean()

plt.figure(figsize=(16, 12))
for idx, metric in enumerate(metrics):
    plt.subplot(3, 3, idx + 1)
    sns.barplot(x=noise_level_diff_summary.index, y=noise_level_diff_summary[f'{metric}_diff'], palette='viridis')
    plt.title(f'Average {metric} Difference by Noise Level')
    plt.xlabel('Noise Level')
    plt.ylabel(f'{metric} Difference')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3 - Box Plots

# %%
# 3. Box Plots to Show Metric Distributions
plt.figure(figsize=(20, 20))
for idx, metric in enumerate(metrics):
    plt.subplot(4, 2, idx + 1)
    sns.boxplot(x='Noise_level', y=metric, hue='Noise_level', data=real_df, palette='Set2', dodge=True)
    sns.boxplot(x='Noise_level', y=metric, hue='Noise_level', data=syn_df, palette='Set1', dodge=True)
    plt.title(f'Box Plot for {metric} Distribution by Noise Level')
    plt.xlabel('Noise Level')
    plt.ylabel(metric)
plt.tight_layout()
plt.show()

# %% [markdown]
# 4 - Hypothesis Testing

# %%
for idx, metric in enumerate(metrics):
    print(f"{metric}:")
    for noise_level in ['high', 'mid', 'low']:

        real_data = real_df[real_df['Noise Level'] == noise_level][metric]
        syn_data = syn_df[syn_df['Noise Level'] == noise_level][metric]

        # Normality Test - Shapiro-Wilk
        shapiro_syn = shapiro(real_data)
        shapiro_real = shapiro(syn_data)
        print(f"Shapiro Test for Real {metric} - {noise_level} noise - p-value: {shapiro_real.pvalue}")
        print(f"Shapiro Test for Synthetic {metric} - {noise_level} noise - p-value: {shapiro_syn.pvalue}")
        print("--------------------------------------------------------------------------------")

        # Variance Homogeneity Test - Levene's Test
        levene_test = levene(syn_data, real_data)
        print(f"Levene's Test for Equal Variance {metric} - {noise_level} noise - p-value: {levene_test.pvalue}")
        print("--------------------------------------------------------------------------------")

        # If data is normal and variances are equal, use t-test
        if shapiro_syn.pvalue > 0.05 and shapiro_real.pvalue > 0.05 and levene_test.pvalue > 0.05:
            t_stat, t_pvalue = ttest_ind(syn_data, real_data)
            print(f"T-Test - t-statistic: {t_stat}, p-value: {t_pvalue}")
            print("--------------------------------------------------------------------------------")

            # Analysis: The t-test checks if there is a significant difference in means between the two groups.
            # Expectation: If p-value < 0.05, it suggests that the means of the synthetic and real PSNR values are significantly different.
        else:
            # If data is not normal, use Mann-Whitney U Test
            u_stat, u_pvalue = mannwhitneyu(syn_data, real_data)
            print(f"Mann-Whitney U Test - u-statistic: {u_stat}, p-value: {u_pvalue}")
            print("--------------------------------------------------------------------------------")


        # Kolmogorov-Smirnov Test
        ks_stat, ks_pvalue = ks_2samp(syn_data, real_data)
        print(f"Kolmogorov-Smirnov Test - ks-statistic: {ks_stat}, p-value: {ks_pvalue}")
        print("--------------------------------------------------------------------------------")

        print()

    print()
# Out:
# PSNR:
# Shapiro Test for Real PSNR - hight noise - p-value: 3.298567911949111e-10
# Shapiro Test for Synthetic PSNR - hight noise - p-value: 6.447524292211874e-06
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance PSNR - hight noise - p-value: 0.9573132411376546
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 47162.5, p-value: 0.3085219405801942
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.08, p-value: 0.2926468667924955
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real PSNR - mid noise - p-value: 0.0004251505243930697
# Shapiro Test for Synthetic PSNR - mid noise - p-value: 0.00018292035695365003
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance PSNR - mid noise - p-value: 0.48557137649627224
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 49182.0, p-value: 0.04889140210868837
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.12333333333333334, p-value: 0.020771538379556198
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real PSNR - low noise - p-value: 1.425810641209464e-14
# Shapiro Test for Synthetic PSNR - low noise - p-value: 4.603307351137385e-14
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance PSNR - low noise - p-value: 0.5958255947284681
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 46819.0, p-value: 0.3917015622093669
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.05333333333333334, p-value: 0.7879453299387805
# --------------------------------------------------------------------------------
#
#
# SSIM:
# Shapiro Test for Real SSIM - hight noise - p-value: 3.272830538241182e-10
# Shapiro Test for Synthetic SSIM - hight noise - p-value: 3.3824573240886547e-12
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance SSIM - hight noise - p-value: 0.44549793307467744
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 44190.5, p-value: 0.7031621754267925
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.04666666666666667, p-value: 0.9003231885744891
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real SSIM - mid noise - p-value: 1.4094787361787287e-21
# Shapiro Test for Synthetic SSIM - mid noise - p-value: 1.5979492579955182e-18
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance SSIM - mid noise - p-value: 0.13104606494323168
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 50625.0, p-value: 0.008067846925253714
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.11666666666666667, p-value: 0.033619141621670706
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real SSIM - low noise - p-value: 1.0622967973992355e-06
# Shapiro Test for Synthetic SSIM - low noise - p-value: 1.3740881910271539e-07
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance SSIM - low noise - p-value: 0.8805512642472303
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 44292.5, p-value: 0.7391298935639541
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.04, p-value: 0.9704671760269938
# --------------------------------------------------------------------------------
#
#
# LPIPS:
# Shapiro Test for Real LPIPS - hight noise - p-value: 0.48672132578326893
# Shapiro Test for Synthetic LPIPS - hight noise - p-value: 0.00122041686123402
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance LPIPS - hight noise - p-value: 0.09470834404225285
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 46801.5, p-value: 0.39627445636505043
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.08, p-value: 0.2926468667924955
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real LPIPS - mid noise - p-value: 3.946648269850502e-20
# Shapiro Test for Synthetic LPIPS - mid noise - p-value: 2.1785982331997662e-18
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance LPIPS - mid noise - p-value: 0.12139249132858262
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 39408.0, p-value: 0.008446810699181564
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.13333333333333333, p-value: 0.00958895491281293
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real LPIPS - low noise - p-value: 1.0268918141138036e-11
# Shapiro Test for Synthetic LPIPS - low noise - p-value: 9.428028830681639e-12
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance LPIPS - low noise - p-value: 0.42775135234708406
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 46605.0, p-value: 0.449805481201607
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.06, p-value: 0.65357468169842
# --------------------------------------------------------------------------------
#
#
# BRISQUE:
# Shapiro Test for Real BRISQUE - hight noise - p-value: 0.12026321656142386
# Shapiro Test for Synthetic BRISQUE - hight noise - p-value: 0.17784630682471242
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance BRISQUE - hight noise - p-value: 0.09838629298308094
# --------------------------------------------------------------------------------
# T-Test - t-statistic: -0.7977415702862903, p-value: 0.4253371289370701
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.09666666666666666, p-value: 0.12122695053622792
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real BRISQUE - mid noise - p-value: 8.16172707759404e-18
# Shapiro Test for Synthetic BRISQUE - mid noise - p-value: 1.0468373348808515e-16
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance BRISQUE - mid noise - p-value: 0.2319607225589296
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 47978.5, p-value: 0.16071399220415905
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.08666666666666667, p-value: 0.21005749381264038
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real BRISQUE - low noise - p-value: 3.406107847452326e-10
# Shapiro Test for Synthetic BRISQUE - low noise - p-value: 6.294106410100049e-10
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance BRISQUE - low noise - p-value: 0.046363151663553724
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 40858.0, p-value: 0.05109311011874114
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.13333333333333333, p-value: 0.00958895491281293
# --------------------------------------------------------------------------------
#
#
# MUSIQ:
# Shapiro Test for Real MUSIQ - hight noise - p-value: 0.030810508812061765
# Shapiro Test for Synthetic MUSIQ - hight noise - p-value: 0.2842503602053014
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance MUSIQ - hight noise - p-value: 0.29853470585891156
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 43799.5, p-value: 0.5719277959146561
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.08, p-value: 0.2926468667924955
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real MUSIQ - mid noise - p-value: 1.348522438575356e-13
# Shapiro Test for Synthetic MUSIQ - mid noise - p-value: 5.696419725905109e-12
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance MUSIQ - mid noise - p-value: 0.52489293889601
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 47267.5, p-value: 0.2856176802529571
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.08333333333333333, p-value: 0.2488247843957968
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real MUSIQ - low noise - p-value: 3.5781297344457428e-09
# Shapiro Test for Synthetic MUSIQ - low noise - p-value: 2.0626618590091207e-10
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance MUSIQ - low noise - p-value: 0.8847846996794582
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 45176.0, p-value: 0.934119794871002
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.04666666666666667, p-value: 0.9003231885744891
# --------------------------------------------------------------------------------
#
#
# NIMA:
# Shapiro Test for Real NIMA - hight noise - p-value: 2.0303204863919544e-09
# Shapiro Test for Synthetic NIMA - hight noise - p-value: 1.8214062632626353e-08
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance NIMA - hight noise - p-value: 0.22649675495008303
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 43195.0, p-value: 0.3953574058745801
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.07666666666666666, p-value: 0.34165950354815394
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real NIMA - mid noise - p-value: 1.6292048349811442e-11
# Shapiro Test for Synthetic NIMA - mid noise - p-value: 2.1866592776464596e-12
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance NIMA - mid noise - p-value: 0.8407566540697138
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 46765.5, p-value: 0.4057834372958077
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.07, p-value: 0.4548928024568597
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real NIMA - low noise - p-value: 5.794901232925094e-05
# Shapiro Test for Synthetic NIMA - low noise - p-value: 0.06804188489143052
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance NIMA - low noise - p-value: 0.5803685190860293
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 41639.0, p-value: 0.11345872529235033
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.09, p-value: 0.17609362474930004
# --------------------------------------------------------------------------------
#
#
# NIQE:
# Shapiro Test for Real NIQE - hight noise - p-value: 0.00018568031559517754
# Shapiro Test for Synthetic NIQE - hight noise - p-value: 6.722409525604273e-08
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance NIQE - hight noise - p-value: 0.15034880997330627
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 43189.5, p-value: 0.3939188600315362
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.06666666666666667, p-value: 0.5182685170344619
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real NIQE - mid noise - p-value: 3.8655398863056903e-13
# Shapiro Test for Synthetic NIQE - mid noise - p-value: 5.040703044325487e-13
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance NIQE - mid noise - p-value: 0.7063267343303203
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 47106.0, p-value: 0.3213360124323845
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.07, p-value: 0.4548928024568597
# --------------------------------------------------------------------------------
#
# Shapiro Test for Real NIQE - low noise - p-value: 5.0890498787653446e-14
# Shapiro Test for Synthetic NIQE - low noise - p-value: 3.882508729956334e-12
# --------------------------------------------------------------------------------
# Levene's Test for Equal Variance NIQE - low noise - p-value: 0.8117438927249307
# --------------------------------------------------------------------------------
# Mann-Whitney U Test - u-statistic: 42337.0, p-value: 0.2098165948825912
# --------------------------------------------------------------------------------
# Kolmogorov-Smirnov Test - ks-statistic: 0.08333333333333333, p-value: 0.2488247843957968
# --------------------------------------------------------------------------------

# %% [markdown]
# 5 - Effect Size (Cohen's d)

# %%
# Step 4: Effect Size (Cohen's d)
def cohens_d(x, y):
    nx, ny = len(x), len(y)
    dof = nx + ny - 2
    pooled_std = np.sqrt(((nx - 1) * np.std(x, ddof=1) ** 2 + (ny - 1) * np.std(y, ddof=1) ** 2) / dof)
    return (np.mean(x) - np.mean(y)) / pooled_std


for idx, metric in enumerate(metrics):
    print(f"{metric}:")
    for noise_level in ['hight', 'mid', 'low']:

        real_data = real_df[real_df['Noise Level'] == noise_level][metric]
        syn_data = syn_df[syn_df['Noise Level'] == noise_level][metric]

        d = cohens_d(syn_data, real_data)
        print(f"Cohen's d - {noise_level} noise: {d}")

    print()
# Out:
# PSNR:
# Cohen's d - hight noise: 0.047051769714420676
# Cohen's d - mid noise: 0.1451020723113047
# Cohen's d - low noise: 0.06616309242439976
#
# SSIM:
# Cohen's d - hight noise: -0.029162202046818717
# Cohen's d - mid noise: 0.1721584702599087
# Cohen's d - low noise: -0.036562897809226017
#
# LPIPS:
# Cohen's d - hight noise: 0.09676422348197196
# Cohen's d - mid noise: -0.16895554867019347
# Cohen's d - low noise: 0.06647507731602827
#
# BRISQUE:
# Cohen's d - hight noise: -0.06513532646026715
# Cohen's d - mid noise: 0.11325953767843491
# Cohen's d - low noise: -0.10504942303665775
#
# MUSIQ:
# Cohen's d - hight noise: -0.02109015804478087
# Cohen's d - mid noise: 0.07966779598643015
# Cohen's d - low noise: 0.007572965877619396
#
# NIMA:
# Cohen's d - hight noise: -0.0754243918032218
# Cohen's d - mid noise: 0.04374444400663136
# Cohen's d - low noise: -0.1107029801287088
#
# NIQE:
# Cohen's d - hight noise: -0.11255744465110244
# Cohen's d - mid noise: 0.07065598679072004
# Cohen's d - low noise: -0.08615358107589378

# %% [markdown]
# 6 - ROC Curve Analysis

# %%
plt.figure(figsize=(20, 30))

for idx, metric in enumerate(metrics):
    for noise_level in ['high', 'mid', 'low']:

        real_data = real_df[real_df['Noise_level'] == noise_level][metric]
        syn_data = syn_df[syn_df['Noise_level'] == noise_level][metric]

        psnr_values = np.concatenate((real_data, syn_data))
        labels = np.array([0] * len(real_data) + [1] * len(syn_data))  # 0 for real, 1 for synthetic

        # Plotting the ROC curve
        fpr, tpr, thresholds = roc_curve(labels, psnr_values)
        roc_auc = auc(fpr, tpr)

        plt.subplot(len(metrics), 3, idx * 3 + ['high', 'mid', 'low'].index(noise_level) + 1)
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve - {metric} - {noise_level} noise (area = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.title(f'ROC for {metric} - {noise_level} Noise')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc='lower right')

plt.tight_layout()
plt.show()
